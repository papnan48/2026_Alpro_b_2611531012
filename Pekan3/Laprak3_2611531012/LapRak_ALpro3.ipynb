# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **ALGORITMA & PEMOGRAMAN**
#
# **“OPERATOR PADA PYTHON”**
#
# **Disusun Oleh :**
#
# **Afnan Feyza**
#
# **2611531012**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Muhammad Galid Alvero**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkat-Nya, sehingga penulis dapat menyelesaikan laporan praktikum ini yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan dan penerapan berbagai operasi dasar menggunakan bahasa Python.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep operator aritmatika, perbandingan, logika, penugasan, keanggotaan, identitas, serta bitwise pada proyek nyata.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, September 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Python menyediakan berbagai jenis operator yang berfungsi untuk memanipulasi nilai atau variabel. Pemahaman yang mendalam tentang jenis dan penggunaan operator sangat penting dalam pemrograman untuk menyelesaikan suatu masalah matematis dan logis secara komputasional. Pada praktikum ini, dipelajari berbagai macam jenis operator yang dapat diimplementasikan dalam struktur logika bahasa pemrograman Python.
#
# ## 1.2 Tujuan
# 1. Mampu memahami berbagai jenis operator di dalam bahasa pemrograman Python.
# 2. Mampu menerapkan operasi matematis, bitwise, serta perbandingan logika dalam skrip kode.
# 3. Mampu menyelesaikan sebuah studi kasus terintegrasi menggunakan penggabungan beragam operasi logika dan kondisi.
#
# ## 1.3 Manfaat
# 1. Mahasiswa dapat mengoptimalkan penulisan kode program dengan menggunakan operator yang paling tepat dan efisien.
# 2. Mahasiswa dapat membangun logika algoritmik yang kuat dalam merancang suatu alur dari aplikasi atau sistem transaksi.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Berdasarkan modul praktikum, operator pada Python digunakan untuk melakukan operasi pada variabel dan nilai. Terdapat berbagai jenis operator yang digunakan, antara lain:
# 1. **Operator Aritmatika**: Digunakan untuk operasi matematika. Contohnya meliputi penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), modulus atau sisa bagi (%), dan pangkat (**).
# 2. **Operator Perbandingan (Comparison)**: Digunakan untuk membandingkan dua nilai dan menghasilkan nilai *boolean* True atau False. Operator yang tersedia adalah sama dengan (==), tidak sama dengan (!=), lebih besar (>), lebih kecil (<), lebih besar atau sama dengan (>=), dan lebih kecil atau sama dengan (<=).
# 3. **Operator Logika**: Digunakan untuk menggabungkan kondisi, meliputi `and` (bernilai True jika semua kondisi True), `or` (bernilai True jika salah satu kondisi True), dan `not` (membalik nilai logika).
# 4. **Operator Penugasan (Assignment)**: Digunakan untuk memberikan nilai ke suatu variabel. Contoh dari implementasinya yaitu `=`, `+=`, `-=`, `*=`, `/=`, `%=`, dan `**=`.
# 5. **Operator Keanggotaan (Membership)**: Digunakan untuk memeriksa apakah suatu nilai ada dalam suatu koleksi data, dengan memanfaatkan instruksi `in` dan `not in`.
# 6. **Operator Identitas (Identity)**: Digunakan untuk membandingkan lokasi objek di dalam memori. Operator `is` membandingkan kesamaan objek secara utuh, sedangkan `is not` menyatakan objek yang berbeda. Operator identitas berbeda dengan `==` yang hanya membandingkan isi/nilai suatu objek.
# 7. **Operator Bitwise**: Bekerja pada perhitungan *level bit* biner. Contoh operasi yang dapat dilakukan adalah AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>).

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program Aritmatika "aritmatika_2611531012.py"

# %%
# Buat file dengan nama aritmatika_2611531012.py
# Buat program untuk operator aritmatika dalam python
# Nama variabel ditambah 4 digit NIM terakhir contoh: angka1_1012
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_1012 = int(input("Input angka-1: "))
angka2_1012 = int(input("Input angka-2: "))

# Penjumlahan
hasil_1012 = angka1_1012 + angka2_1012
print("\nOperator Penjumlahan")
print("Hasil =", hasil_1012)

# Pengurangan
hasil_1012 = angka1_1012 - angka2_1012
print("\nOperator Pengurangan")
print("Hasil =", hasil_1012)

# Perkalian
hasil_1012 = angka1_1012 * angka2_1012
print("\nOperator Perkalian")
print("Hasil =", hasil_1012)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_1012 !=0:
    hasil_1012 = angka1_1012 / angka2_1012
    print("\nOperator Pembagian")
    print("Hasil =", hasil_1012)

    hasil_1012 = angka1_1012 // angka2_1012
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_1012)

    hasil_1012 = angka1_1012 % angka2_1012
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_1012)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_1012 = angka1_1012 ** angka2_1012
print("\nOperator Pangkat")
print("Hasil =", hasil_1012)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/aritmatika.png" width="400"><br>
# <em>Gambar 2.1 : Output Program Aritmatika</em>
# </div>
#
# **Penjelasan :**
# Program di atas menerapkan pengoperasian matematis dasar dengan menerima dua input nilai dari pengguna yang langsung dikonversikan ke integer menggunakan fungsi `int(input())`. Khusus untuk pengoperasian pembagian, terdapat pengamanan selektif `if-else` agar program tidak mengalami pesan error, yang mewajibkan variabel pembagi angka2_1012 tidak bernilai 0.

# %% [markdown]
# ### 2.2.2 Program Assignment "assignment_2611531012"

# %%
# Buat file dengan nama assignment_2611531012.py
# Nama variabel ditambah 4 digit NIM terakhir contoh: angka1_1012
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam python

angka1_1012 = int(input("Input angka-1: "))
angka2_1012 = int(input("Input angka-2: "))

print("\nNilai awal angka1 =", angka1_1012)
print("\nNilai angka2 =", angka2_1012)

# Assignmant biasa
hasil_1012 = angka1_1012
print("\nAssignment biasa (=)")
print("Hasil =", hasil_1012)

# Assignment penambahan
hasil_1012 = angka1_1012
hasil_1012 += angka2_1012
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_1012)

# Assignment pengurangan
hasil_1012 = angka1_1012
hasil_1012 -= angka2_1012
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_1012)

# Assignment perkalian
hasil_1012 = angka1_1012
hasil_1012 *= angka2_1012
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_1012)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_1012 !=0:
    hasil_1012 = angka1_1012
    hasil_1012 /= angka2_1012
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_1012)
    # Operator tambahan
    hasil_1012 = angka1_1012
    hasil_1012 //= angka2_1012
    print("\nAssignment pembagian bulat(//=)")
    print("Hasil =", hasil_1012)
    hasil_1012 = angka1_1012
    hasil_1012 %= angka2_1012
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_1012)
else:
    print("\nPembagian tidak dapat dilakukan")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_1012 = angka1_1012
hasil_1012 **= angka2_1012
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_1012)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/assignment.png" width="400"><br>
# <em>Gambar 2.2 : Output Program Assignment</em>
# </div>
#
#
# **Penjelasan program assignment di atas:**
#
# Program menugaskan kembali nilai `hasil_1012` menggunakan assignment kombo seperti `+=`, `-=`, `*=`, `/=`, `//=`, `%=`, dan `**=`. Variabel penampung hasil harus selalu diinisialisasi atau disegarkan (refresh) setiap masuk baris perintah yang baru sehingga kalkulasi penambahan maupun perpangkatannya valid mengacu pada nilai orisinal dari variabel `angka1_1012`.

# %% [markdown]
# ### 2.2.3 Program Bitwise "bitwise_2611531012"

# %%
# Buat file dengan nama bitwise_2611531012.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1012
# Program ini menggunakan fungsi input()

print("\n=============================")
print("3. OPERATOR BITWISE")
print("=============================")

angka1_1012 = int(input("Masukkan angka bitwise-1: "))
angka2_1012 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_1012, "| biner =", bin(angka1_1012))
print("angka2 =", angka2_1012, "| biner =", bin(angka2_1012))

# Bitwise AND
hasil_1012 = angka1_1012 & angka2_1012
print("\nBitwise AND (&)")
print(angka1_1012, "&", angka2_1012, "=", hasil_1012)
print("Biner hasil =", bin(hasil_1012))
print("Biner hasil (8 bit) =", format(hasil_1012, "08b"))

# Bitwise OR
hasil_1012 = angka1_1012 | angka2_1012
print("\nBitwise OR (|)")
print(angka1_1012, "|", angka2_1012, "=", hasil_1012)
print("Biner hasil =", bin(hasil_1012))
print("Biner hasil (8 bit) =", format(hasil_1012, "08b"))

# Bitwise XOR
hasil_1012 = angka1_1012 ^ angka2_1012
print("\nBitwise XOR (^)")
print(angka1_1012, "^", angka2_1012, "=", hasil_1012)
print("Biner hasil =", bin(hasil_1012))
print("Biner hasil (8 bit) =", format(hasil_1012, "08b"))

# Bitwise NOT
hasil_1012 = ~angka1_1012
print("\nBitwise NOT (~)")
print("~", angka1_1012, "=", hasil_1012)
print("Biner hasil =", bin(hasil_1012))
print("Biner hasil (8 bit) =", format(hasil_1012, "08b"))

# Bitwise geser kiri
jumlah_geser_1012 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_1012 = angka1_1012 << jumlah_geser_1012
print("\nBitwise geser kiri (<<)")
print(angka1_1012, "<<", jumlah_geser_1012, "=", hasil_1012)
print("Biner hasil =", bin(hasil_1012))
print("Biner hasil (8 bit) =", format(hasil_1012, "08b"))

# Bitwise geser kanan
hasil_1012 = angka1_1012 >> jumlah_geser_1012
print("\nBitwise geser kanan (>>)")
print(angka1_1012, ">>", jumlah_geser_1012, "=", hasil_1012)
print("Biner hasil =", bin(hasil_1012))
print("Biner hasil (8 bit) =", format(hasil_1012, "08b"))

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/bitwise.png" width="400"><br>
# <em>Gambar 2.3 : Output Program Bitwise</em>
# </div>
#
#
# **Penjelasan program bitwise di atas:**
#
# Program ini mengeksekusi operasi logika dasar berbasis bit seperti `AND`, `OR`, `XOR`, hingga invers `NOT` di mana setiap perhitungannya dikonversikan ke dalam format bilangan berbasis dua (biner) menggunakan instruksi `bin()` serta mencetak format kustom 8-bit `08b`. Pengguna juga diizinkan menyesuaikan pergeseran rentang bit secara bebas dengan input yang ditampung variabel `jumlah_geser_1012`.

# %% [markdown]
# ### 2.2.4 Program Lainnya "lainnya_2611531012"

# %%
# Buat file dengan nama lainnya_2611531012.py
# Nama variabel ditambah 4 digit terakhir contoh: angka1_1012
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("=================================")
print("1, OPERATOR KEANGGOTAAN")
print("=================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_1012 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_1012 = [int(angka.strip()) for angka in input_data_1012.split(",")]

nilai_dicari_1012 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_1012 = nilai_dicari_1012 in data_1012
print ("\nOperator keanggotaan IN")
print(nilai_dicari_1012, "in", data_1012, "=", hasil_1012)

# Operator not in
hasil_1012 = nilai_dicari_1012 not in data_1012
print ("\nOperator keanggotaan NOT IN")
print(nilai_dicari_1012, "not in", data_1012, "=", hasil_1012)


print("\n============================")
print("2. OPERATOR IDENTITAS")
print("============================")

# objek1 menggunakan list dari input pengguna
objek1_1012 = data_1012

# objek2 merujuk pada objek yang sama dengan objek 1
objek2_1012 = objek1_1012

# objek2 memiliki isi sama, tetapi merupakan objek baru
objek3_1012 = data_1012.copy()

print("objek1 =", objek1_1012)
print("objek2 =", objek2_1012)
print("objek3 =", objek3_1012)

# Operator is
hasil_1012 = objek1_1012 is objek2_1012
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_1012)

# Operator is not
hasil_1012 = objek1_1012 is not objek3_1012
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_1012)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek 3 =", objek1_1012 is objek3_1012)
print("objek1 == objek3 =", objek1_1012 == objek3_1012)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/lainnya.png" width="400"><br>
# <em>Gambar 2.4 : Output Program Lainnya</em>
# </div>
#
# **Penjelasan :**
# Program mendemonstrasikan pemeriksan keanggotaan dengan mengecek apakah inputan tersimpan di dalam list (`in` dan `not in`) setelah string angka dilakukan metode pemisahan koma `.split(",")`. Pada tahapan kedua, program memperlihatkan perbedaan antara menginisialisasi rujukan ke objek yang sama `objek2_1012 = objek1_1012` dengan pembentukan salinan mandiri `data_1012.copy()`. Hasil `is` dan `is not` merepresentasikan perbandingan lokasi memori, bukan sekadar membandingkan kesetaraan nilai biasa.

# %% [markdown]
# ### 2.2.5 Program Logika "logika_2611531012"

# %%
# Buat file dengan nama logika_2611531012.py
# Nama variabel ditambah 4 digit NIM terakhir contoh: a1_1012
# Program ini menggunakan fungsi input()
# Program operator logika dalam Python

# memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_1012 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_1012 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1 =", a1_1012)
print("A2 =", a2_1012)

# Konjungsi: bernilai True jika keduanya True
hasil_1012 = a1_1012 and a2_1012
print("\nKonjungsi (AND)")
print("A1 and A2 =", hasil_1012)

# Disjungsi: bernilai True jika salah satunya True
hasil_1012 = a1_1012 or a2_1012
print("\nDisjungsi (OR)")
print("A1 or A2 =", hasil_1012)

# Negasi A1: membalik nilai A1
hasil_1012 = not a1_1012
print("\nNegasi A1 (NOT)")
print("not A1 =", hasil_1012)

# Negasi A2: membalik nilai A2
hasil_1012 = not a2_1012
print("\nNegasi A2 (NOT)")
print("not A2 =", hasil_1012)

# XOR: bernilai True jika kedua nilai berbeda
hasil_1012 = a1_1012 != a2_1012
print("\nDisjungsi Eksklusif (XOR)")
print("A1 XOR A2 =", hasil_1012)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/logika.png" width="400"><br>
# <em>Gambar 2.5 : Output Program Logika</em>
# </div>
#
# **Penjelasan :**
# Program membaca kondisi masukan berbasis huruf namun disanitasi sehingga bersifat absolut tidak case-sensitive melalui perpaduan instuksi pembersihan spasi `.strip()` dan `.lower()`. Nilai akhir akan diproses menggunakan logika konjungsi (`and`), disjungsi fleksibel (`or`), dan operan pembalikan arah (`not`) dengan hasil output boolean sejati.

# %% [markdown]
# ### 2.2.6 Program Perbandingan "perbandingan_2611531012"

# %%
# Buat file dengan nama perbandingan_2611531012.py
# Nama variabel ditambah 4 digit NIM terakhir contoh: angka1_1012
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_1012 = int(input("Input angka-1: "))
angka2_1012 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_1012 = angka1_1012 > angka2_1012
print("\nOperator lebih besar dari")
print("angka1 > angka2 =", hasil_1012)

# Lebih kecil dari
hasil_1012 = angka1_1012 < angka2_1012
print("\nOperator lebih kecil dari")
print("angka1 < angka2 =", hasil_1012)

# Lebih besar dari atau sama dengan
hasil_1012 = angka1_1012 >= angka2_1012
print("\nOperator lebih besar dari atau sama dengan")
print("angka1 >= angka2 =", hasil_1012)

# Lebih kecil dari atau sama dengan
hasil_1012 = angka1_1012 <= angka2_1012
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1 <= angka2 =", hasil_1012)

# Sama dengan
hasil_1012 = angka1_1012 == angka2_1012
print("\nOperator sama dengan")
print("angka1 == angka2 =", hasil_1012)

# Tidak sama dengan
hasil_1012 = angka1_1012 != angka2_1012
print("\nOperator tidak sama dengan")
print("angka1 != angka2 =", hasil_1012)

# Tambahan: perbandingan berantai dalam Python
hasil_1012 = 0 < angka1_1012 <100
print("\nPerbandingan berantai")
print("0 < angka1 < 100 =", hasil_1012)

hasil_1012 = 0 < angka2_1012 < 100
print("0 < angka2 < 100 =", hasil_1012)

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/perbandingan.png" width="400"><br>
# <em>Gambar 2.6 : Output Program Perbandingan</em>
# </div>
#
# **Penjelasan :**
# Selain melakukan uji parameter yang bersifat dasar seperti mendeteksi bilangan terbesar, terkecil, tidak sama dengan `!=`, dan persis sama `==`. Program ini juga menyematkan validasi berantai layaknya batasan rentang pada ilmu matematika konvensional `0 < x < 100` untuk membuktikan fungsionalitas sintaks di dalam Python sangat dinamis dan luwes dibaca.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
# Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "Tugas3_2611531012.py"

# %%
# tugas3_2611531012.py
# Sistem Simulasi Transaksi dan Validasi Akses Toko

print("=== SISTEM TRANSAKSI TOKO ===\n")

# Input Data Pelanggan
nama_1012 = input("Masukkan Nama Pelanggan : ")
status_1012 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_1012 = int(input("Masukkan Total Belanja : "))
jumlah_barang_1012 = int(input("Masukkan Jumlah Barang : "))
kode_promo_input_1012 = input("Masukkan Kode Promo : ")

# Operator Keanggotaan
daftar_promo_1012 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
promo_tersedia_1012 = kode_promo_input_1012 in daftar_promo_1012
promo_tidak_valid_1012 = kode_promo_input_1012 not in daftar_promo_1012

# Operator Perbandingan & Logika
syarat_belanja_1012 = total_belanja_1012 >= 200000
syarat_barang_1012 = jumlah_barang_1012 >= 3
is_member_1012 = status_1012 == "member"

# Logika Penggabungan (and)
dapat_diskon_1012 = is_member_1012 and syarat_belanja_1012
dapat_promo_1012 = promo_tersedia_1012 and syarat_barang_1012

# Operator Identitas
promo_ref_1012 = daftar_promo_1012
promo_copy_1012 = daftar_promo_1012.copy()
# Membuktikan identitas objek
is_same_object_1012 = promo_ref_1012 is daftar_promo_1012
is_diff_object_1012 = promo_copy_1012 is not daftar_promo_1012

# Operator Aritmatika & Penugasan
besaran_diskon_1012 = 0
if dapat_diskon_1012:
    besaran_diskon_1012 = total_belanja_1012 * 10 // 100  # Diskon 10% (Aritmatika Perkalian & Pembagian Bulat)

# Assignment
total_pembayaran_1012 = total_belanja_1012
total_pembayaran_1012 -= besaran_diskon_1012  # Augmented assignment pengurangan

# Aritmatika lanjutan
rata_rata_harga_1012 = total_belanja_1012 // jumlah_barang_1012
sisa_bagi_1012 = total_belanja_1012 % jumlah_barang_1012

# 6. Operator Bitwise
# 0001 (1) = Member | 0010 (2) = Belanja >= 200k | 0100 (4) = Barang >= 3 | 1000 (8) = Promo
status_code_1012 = 0
if is_member_1012: status_code_1012 |= 1
if syarat_belanja_1012: status_code_1012 |= 2
if syarat_barang_1012: status_code_1012 |= 4
if promo_tersedia_1012: status_code_1012 |= 8

cek_member_bitwise_1012 = status_code_1012 & 1
cek_promo_bitwise_1012 = status_code_1012 & 8

# Perbandingan Status (XOR) dan Shift
kode_referensi_1012 = 11  # 1011 Biner
hasil_xor_1012 = status_code_1012 ^ kode_referensi_1012
shift_kiri_1012 = status_code_1012 << 1

# === OUTPUT PROGRAM ===
print("\n=== DATA TRANSAKSI ===")
print(f"Nama Pelanggan       : {nama_1012}")
print(f"Status Pelanggan     : {status_1012}")
print(f"Total Belanja        : Rp{total_belanja_1012}")
print(f"Jumlah Barang        : {jumlah_barang_1012}")
print(f"Kode Promo           : {kode_promo_input_1012}")

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000        : {syarat_belanja_1012}")
print(f"Jumlah Barang >= 3         : {syarat_barang_1012}")
print(f"Status Member              : {is_member_1012}")
print(f"Kode Promo Tersedia        : {promo_tersedia_1012}")
print(f"Mendapatkan Diskon         : {dapat_diskon_1012}")
print(f"Mendapatkan Promo          : {dapat_promo_1012}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                     : Rp{besaran_diskon_1012}")
print(f"Total Pembayaran           : Rp{total_pembayaran_1012}")
print(f"Rata-rata Harga Barang     : Rp{rata_rata_harga_1012}")
print(f"Sisa Bagi (Modulus)        : Rp{sisa_bagi_1012}")

print("\n=== HAK AKSES PELANGGAN ===")
print(f"Kode Hak Akses             : {format(status_code_1012, '04b')}")
print(f"Member Access              : {bool(cek_member_bitwise_1012)}")
print(f"Promo Access               : {bool(cek_promo_bitwise_1012)}")

print("\n=== OPERASI BITWISE ===")
print("=== Kode Status Transaksi ===")
print(f"Kode Biner   : {format(status_code_1012, '04b')}")
print(f"Kode Desimal : {status_code_1012}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(status_code_1012, '04b')} & 0001")
print(f"Hasil Biner   : {format(cek_member_bitwise_1012, '04b')}")
print(f"Hasil Desimal : {cek_member_bitwise_1012}")

print("\nCek Promo")
print(f"{format(status_code_1012, '04b')} & 1000")
print(f"Hasil Biner   : {format(cek_promo_bitwise_1012, '04b')}")
print(f"Hasil Desimal : {cek_promo_bitwise_1012}")

print("\n=== Perbandingan Status ===")
print(f"Kode Transaksi : {format(status_code_1012, '04b')}")
print(f"Kode Referensi : {format(kode_referensi_1012, '04b')}")
print(f"{format(status_code_1012, '04b')} ^ {format(kode_referensi_1012, '04b')}")
print(f"Hasil Biner   : {format(hasil_xor_1012, '04b')}")
print(f"Hasil Desimal : {hasil_xor_1012}")

print("\n=== Shift ===")
print(f"{format(status_code_1012, '04b')} << 1")
print(f"Hasil Biner   : {format(shift_kiri_1012, '05b')}")
print(f"Hasil Desimal : {shift_kiri_1012}")
print("\n=== SELESAI ===")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/tg-tg1.png" width="400"><br>
# <img src="images/tg-tg2.png" width="400"><br>
# <img src="images/tg-tg3.png" width="400"><br>
# <em>Gambar 2.7 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :**
#
# **Output :**
#
# === DATA TRANSAKSI ===
#
# Blok ini mencetak kembali seluruh data mentah ("Afnan", "member", Rp250000, 4, "HEMAT10") yang dimasukkan pada saat input. Tujuannya adalah untuk mengonfirmasi bahwa variabel telah menyimpan nilai dan tipe data yang benar sebelum diproses lebih lanjut.
#
#
# === HASIL VALIDASI ===
#
# Menampilkan pembuktian nilai boolean dari setiap operasi logika dan perbandingan. Seluruh output mencetak nilai True karena besaran transaksi dan status keanggotaan Afnan berhasil memenuhi semua batas kriteria minimum yang ditetapkan dalam logika kode.
#
#
# === HASIL PERHITUNGAN ===
#
# Menampilkan hasil matematis dari operator aritmatika. Diskon tercetak sebesar Rp25000, sehingga Total Pembayaran menyusut menjadi Rp225000. Rata-rata Harga Barang tercetak presisi di angka Rp62500 berkat operator pembagian bulat (`//`), dan Sisa Bagi adalah Rp0 karena 250.000 habis dibagi 4 tanpa sisa.
#
#
# === HAK AKSES PELANGGAN ===
#
# Menunjukkan representasi string biner dari variabel `status_code_1012`, yaitu `1111`. Baris ini juga memverifikasi ulang bahwa hak akses member dan promo benar-benar aktif (`True`) berdasarkan ektraksi bit tersebut.
#
#
# === OPERASI BITWISE ===
#
# Bagian ini membedah proses operasi level bit (biner) di balik layar:
#     Kode Status Transaksi: Mengonfirmasi bahwa biner `1111` memiliki padanan nilai desimal `15`.
#     Pemeriksaan Status: Menunjukkan cara kerja Bitwise AND (`&`). Saat sandi `1111` disandingkan dengan masking `0001` (untuk mengecek member), hasilnya tetap `0001` (desimal 1). Begitu juga saat dicek dengan `1000` (untuk mengecek promo), hasilnya adalah `1000` (desimal 8). Ini membuktikan bit target dalam kondisi hidup/aktif.
#     Perbandingan Status: Menggunakan Bitwise XOR (`^`) untuk mencari perbedaan antara sandi `1111` dengan kode referensi `1011`. Karena hanya bit ketiga yang berbeda nilainya, outputnya adalah `0100` atau berdesimal `4`.
#     Shift: Menunjukkan hasil dari operator geser kiri (`<< 1`). Sandi `1111` digeser ke kiri sebanyak `1` posisi menjadi `11110`, yang secara matematis melipatgandakan nilai desimalnya dari `15` menjadi `30`.
#
#
# **Penjelasan :**
#
# **Tahap Input Data**
# Program dimulai dengan membaca lima nilai dari pengguna yang disimpan ke dalam variabel dengan akhiran NIM `_1012`. Berdasarkan eksekusi, nilai yang dimasukkan adalah nama "Afnan", status "member", total belanja "250000", jumlah barang "4", dan kode promo "HEMAT10". Data angka langsung dikonversi menjadi tipe integer agar dapat dihitung.
#
# **Tahap Validasi Syarat (Logika, Perbandingan, dan Keanggotaan)**
# Program mengevaluasi kelayakan transaksi menggunakan operator perbandingan (`>=` dan `==`) serta operator keanggotaan (`in`). Karena total belanja Rp250.000 lebih besar dari batas Rp200.000, dan jumlah barang 4 melebihi syarat minimal 3, maka kondisi tersebut bernilai `True`. Selain itu, karena status pelanggan adalah "member" dan "HEMAT10" ada di dalam daftar promo, seluruh syarat dasar terpenuhi. Operator logika `and` kemudian memastikan pelanggan tersebut berhak mendapatkan diskon dan promo (`True`).
#
# **Tahap Perhitungan (Aritmatika & Penugasan)**
# Setelah diskon divalidasi, program menghitung potongan sebesar 10% dari Rp250.000 menggunakan operator aritmatika perkalian (`*`) dan pembagian bulat (`//`), sehingga didapatkan angka Rp25.000. Menggunakan operator augmented assignment (`-=`), nilai total pembayaran dipotong langsung menjadi Rp225.000. Harga rata-rata barang juga dihitung menggunakan pembagian bulat menjadi Rp62.500, dengan hasil sisa bagi (modulus) Rp0.
#
# **Tahap Pengkodean Status Hak Akses (Bitwise)**
# Program merangkum keempat status pelanggan (member, batas belanja, batas barang, dan validitas promo) ke dalam satu sandi biner menggunakan Bitwise OR (`|=`). Karena Afnan memenuhi semua syarat, keempat bit diaktifkan, menghasilkan kode status biner `1111` yang setara dengan nilai desimal 15.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa bahasa pemrograman Python menyediakan serangkaian operator struktural yang tergolong lengkap dan menyeluruh, mulai dari operator komputasi dasar (aritmatika), penyaring (perbandingan, identitas, keanggotaan), pengatur kontrol flow (logika, penugasan), hingga komputasi kalkulasi pada bit-level memori komputer terbawah (bitwise). Dalam konteks implementasi di lingkungan nyata, penggabungan operator ini dimanfaatkan penuh untuk mengelola seleksi kondisi agar dapat memvalidasi data kompleks layaknya membangun sistem keamanan dan integrasi pembayaran toko otomatis.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] A. Kadir, *Dasar Pemrograman Python 3*, Penerbit Andi, Yogyakarta, 2018.
#
# [2] W. D. Yuniarti, *Dasar-Dasar Pemrograman dengan Python*, Deepublish, Sleman, 2019.
#
# [3] N. Suarna dan U. Hayati, *Belajar Algoritma dan Pemrograman Dasar Menggunakan Python*, Sarana Tutorial, 2021.
#
# [4] W. Zarman dan M. F. Wicaksono, *Implementasi Algoritma Dalam Bahasa Python*, Penerbit Informatika, Bandung, 2020.
#
# [5] J. H. Lewerissa, S. Suprianto, M. W. Djibran, *Konsep Dasar Algoritma dan Pemrograman Menggunakan Python*, Deepublish, Sleman, 2022.
